# %% [markdown]
# # 基本GET请求

# %%
# 通过Python代码把百度图片,放在桌面上  
#User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.80 Safari/537.36
import requests 
#1.发送请求
#请求头
#伪装成浏览器请求的形式， 否则有可能报400 bad request的报错
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 Edg/87.0.664.66'
}

# %%
#2.响应 
### 带参数get请求
### 网址是一张上海的照片
response = requests.get(url='http://img.pconline.com.cn/images/upload/upc/tx/itbbs/1310/15/c46/27542208_1381849468633.jpg' ,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
### 获取图片的二进制内容
response.content
# Out:
# b'\xff\xd8\xff\xe1+lExif\x00\x00II*\x00\x08\x00\x00\x00\n\x00\x0f\x01\x02\x00\x12\x00\x00\x00\x86\x00\x00\x00\x10\x01\x02\x00\x0c\x00\x00\x00\x98\x00\x00\x00\x1a\x01\x05\x00\x01\x00\x00\x00\xa4\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00\xac\x00\x00\x00(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x001\x01\x02\x00(\x00\x00\x00\xb4\x00\x00\x002\x01\x02\x00\x14\x00\x00\x00\xdc\x00\x00\x00;\x01\x02\x00\x08\x00\x00\x00\xf0\x00\x00\x00\x98\x82\x02\x00\x0b\x00\x00\x00\xf8\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x00\x04\x01\x00\x00R\x03\x00\x00NIKON CORPORATION\x00NIKON D7000\x00,\x01\x00\x00\x01\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00Adobe Photoshop Lightroom 5.0 (Windows)\x002013:10:15 23:00:56\x00HongHui\x00HONGHUI001\x00\x00#\x00\x9a\x82\x05\x00\x01\x00\x00\x00\xae\x02\x00\x00\x9d\x82\x05\x00\x01\x00\x00\x00\xb6\x02\x00\x00"\x88\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\'\x88\x03\x00\x01\x00\x00\x00d\x00\x00\x000\x88\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00\x00\x90\x07\x00\x04\x00\x00\x000230\x0
# ...

# %%
#将得到的图片保存
with open('shanghai.png','wb') as f:
    f.write(response.content)
    f.close()

# %%
response = requests.get(url='https://zhuanlan.zhihu.com/p/112526698' ,headers=headers)

# %%
response.text
# Out:
# '<!doctype html>\n<html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">Python爬虫笔记汇总 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta data-react-helmet="true" name="keywords" content="Python 开发,python爬虫,网页爬虫"/><meta data-react-helmet="true" name="description" content="超长警告⚠⚠慎入 参考源：中国MOOC，B站视频（遗憾已下架） 案例：课程案例+实践案例 传送门：Python网络爬虫与信息提取_中国大学MOOC(慕课)文中介绍的比较详细的有，requests库，urllib.request库，BeautifulSou…"/><meta data-react-helmet="true" property="og:title" content="Python爬虫笔记汇总"/><meta data-react-helmet="true" property="og:url" content="https://zhuanlan.zhihu.com/p/112526698"/><meta data-react-helmet="true" property="og:description" content=
# ...

# %% [markdown]
# # 响应

# %%
response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='_xsrf', value='a4a44034-5799-49f0-b755-262a92de2eb2', port=None, port_specified=False, domain='.zhihu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='_zap', value='bb1ced79-c163-428d-aa28-43f6c2a6bdfe', port=None, port_specified=False, domain='.zhihu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1672282103, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='d_c0', value='"AOCaMg0taxKPTvP7aN-b9NtAL_YScfZVhgA=|1609210103"', port=None, port_specified=False, domain='.zhihu.com', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1703818103, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name=
# ...

# %%
response.url
# Out:
# 'https://zhuanlan.zhihu.com/p/112526698'

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# # BeautifulSoup解析库
# #### 大部分情况下可以代替正则表达式来完成网站响应的解析

# %%
from bs4 import BeautifulSoup
html = '''
    <body>
    <header id="header">
    <h3 id="name">小强也可爱</h3>
    <title>标题</title>
      <div class="sns">
        <a href="http://www.kaikeba.com/feed/" target="_blank" rel="nofollow" title="RSS"><i class="fa fa-rss" aria-hidden="true"></i></a>
        <a href="http://kaikeba.com/kaikeba" target="_blank" rel="nofollow" title="Weibo"><i class="fa fa-weibo" aria-hidden="true"></i></a>
                <a href="https://www.kaikeba.com/in/kaikeba" target="_blank" rel="nofollow" title="Linkedin"><i class="fa fa-linkedin" aria-hidden="true"></i></a>
                <a href="mailto:kaikeba@gmail.com" target="_blank" rel="nofollow" title="envelope"><i class="fa fa-envelope" aria-hidden="true"></i></i></a>
          </div>
      <div class="nav">
           <ul><li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>
                <li><a href="http://www.kaikeba.com/about-me/">word</a></li>
                <li><a href="http://www.kaikeba.com/post-search/">nihao</a></li>
                <li><a href="http://www.kaikeba.com/wp-login.php">kkb</a></li>
            </ul>  
      </div>
    </header>
    </body>
'''

soup = BeautifulSoup(html,'lxml')
soup
# Out:
# <html><body>
# <header id="header">
# <h3 id="name">小强也可爱</h3>
# <title>标题</title>
# <div class="sns">
# <a href="http://www.kaikeba.com/feed/" rel="nofollow" target="_blank" title="RSS"><i aria-hidden="true" class="fa fa-rss"></i></a>
# <a href="http://kaikeba.com/kaikeba" rel="nofollow" target="_blank" title="Weibo"><i aria-hidden="true" class="fa fa-weibo"></i></a>
# <a href="https://www.kaikeba.com/in/kaikeba" rel="nofollow" target="_blank" title="Linkedin"><i aria-hidden="true" class="fa fa-linkedin"></i></a>
# <a href="mailto:kaikeba@gmail.com" rel="nofollow" target="_blank" title="envelope"><i aria-hidden="true" class="fa fa-envelope"></i></a>
# </div>
# <div class="nav">
# <ul><li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>
# <li><a href="http://www.kaikeba.com/about-me/">word</a></li>
# <li><a href="http://www.kaikeba.com/post-search/">nihao</a></li>
# <li><a href="http://www.kaikeba.com/wp-login.php">kkb</a></li>
# </ul>
# </div>
# </header>
# ...

# %%
# print(soup.prettify) #soup对象内容  

print(soup.li) #获取li标签,获取第一个
# Out:
# <li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>

# %%
print(soup.title.name)  #标签名字
# Out:
# title

# %%
print(soup.li.contents) #标签里面的内容
# Out:
# [<a href="http://www.kaikeba.com/">hello</a>]

# %%
print(soup.title.parent.name)
# Out:
# header

# %%
soup.li.a.contents
# Out:
# ['hello']

# %%
soup.li.a.string
# Out:
# 'hello'

# %% [markdown]
# ## 标签选择器

# %%
soup.li.a.attrs['href'] #选择属性
# Out:
# 'http://www.kaikeba.com/'

# %%
print(soup.title.string) #标签里面文本
# Out:
# 标题

# %%
soup.ul
# Out:
# <ul><li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>
# <li><a href="http://www.kaikeba.com/about-me/">word</a></li>
# <li><a href="http://www.kaikeba.com/post-search/">nihao</a></li>
# <li><a href="http://www.kaikeba.com/wp-login.php">kkb</a></li>
# </ul>

# %%
soup.ul.children

# %%
for i, child in enumerate(soup.ul.children):
    print(i,child)
# Out:
# 0 <li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>
# 1
#
# 2 <li><a href="http://www.kaikeba.com/about-me/">word</a></li>
# 3
#
# 4 <li><a href="http://www.kaikeba.com/post-search/">nihao</a></li>
# 5
#
# 6 <li><a href="http://www.kaikeba.com/wp-login.php">kkb</a></li>
# 7

# %% [markdown]
# ## 标准选择器

# %%
soup.find_all('li') #会返回所有li标签, 生成一个列表
# Out:
# [<li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>,
#  <li><a href="http://www.kaikeba.com/about-me/">word</a></li>,
#  <li><a href="http://www.kaikeba.com/post-search/">nihao</a></li>,
#  <li><a href="http://www.kaikeba.com/wp-login.php">kkb</a></li>]

# %%
soup.find_all('li')[0].a
# Out:
# <a href="http://www.kaikeba.com/">hello</a>

# %%
type(soup.find_all('li')[0].b)
# Out:
# NoneType

# %%
if 'href' in soup.find_all('li')[0].a:
    print('yes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-1cd3bee4cbaf> in <module>
# ----> 1 if 'href' in soup.find_all('li')[0].a.keys():
#       2     print('yes')
#
# TypeError: 'NoneType' object is not callable

# %%
soup.find_all(attrs={'class':'current-menu-item'}) #获得一个set集合
# Out:
# [<li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>]

# %% [markdown]
# ## CSS选择器

# %%
soup.select('li') #返回所有li标签
# Out:
# [<li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>,
#  <li><a href="http://www.kaikeba.com/about-me/">word</a></li>,
#  <li><a href="http://www.kaikeba.com/post-search/">nihao</a></li>,
#  <li><a href="http://www.kaikeba.com/wp-login.php">kkb</a></li>]

# %%
soup.select('.current-menu-item')
# Out:
# [<li class="current-menu-item"><a href="http://www.kaikeba.com/">hello</a></li>]

# %%
for i in soup.select('li'):
    print(i.get_text())
# Out:
# hello
# word
# nihao
# kkb
